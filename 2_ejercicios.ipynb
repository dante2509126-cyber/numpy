# %% [markdown]
# # Analizando una Imagen

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.11.1-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.64.0-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (123 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.1-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in /home/diavolo/proyecto-prueba/entorno-virtual/lib/python3.14/site-packages (from matplotlib) (2.5.3)
# Requirement already satisfied: packaging>=20.0 in /home/diavolo/proyecto-prueba/entorno-virtual/lib/python3.14/site-packages (from matplotlib) (26.3)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/diavolo/proyecto-prueba/entorno-virtual/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/diavolo/proyecto-prueba/entorno-virtual/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.1-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 955.9 kB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading contourpy-1.3.3-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (363 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.64.0-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 1.1 MB/s eta 0:00:00 MB/s eta 0:00:01:010m
# Downloading kiwisolver-1.5.1-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 1.5 MB/s eta 0:00:001.7 MB/s eta 0:00:01
# Downloading pillow-12.3.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 1.1 MB/s eta 0:00:001.0 MB/s eta 0:00:010m
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib] 6/7 [matplotlib]er]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.64.0 kiwisolver-1.5.1 matplotlib-3.11.1 pillow-12.3.0 pyparsing-3.3.2

# %%
import matplotlib.pyplot as plt 
img = plt.imread('beagle.jpg')
img.shape

img[10,10]
# Out:
# array([22, 35,  5], dtype=uint8)

# %%
rojo = img[10, 10, 0]
verde = img[10, 10, 1]
azul = img[10, 10, 2]

print("Rojo:", rojo)
print("Verde:", verde)
print("Azul:", azul)
# Out:
# Rojo: 22
# Verde: 35
# Azul: 5

# %%
print("Dimensiones:", img.shape)
print("Píxel [10,10]:", img[10,10])

plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
# Dimensiones: (1024, 1024, 3)
# Píxel [10,10]: [22 35  5]

# %%
print("Valor mínimo:", img.min())
print("Valor máximo:", img.max())
print("Media:", img.mean())
print("Desviación estándar:", img.std())
# Out:
# Valor mínimo: 0
# Valor máximo: 255
# Media: 119.40487066904704
# Desviación estándar: 60.93503479873859

# %%
plt.imshow(img[:, :, 0], cmap="Reds")
plt.colorbar()
plt.title("Canal Rojo")
plt.show()

# %%
plt.imshow(img[:, :, 1], cmap="Greens")
plt.colorbar()
plt.title("Canal Verde")
plt.show()

# %%
plt.imshow(img[:, :, 2], cmap="Blues")
plt.colorbar()
plt.title("Canal Azul")
plt.show()

# %%
media_rojo = img[:, :, 0].mean()
media_verde = img[:, :, 1].mean()
media_azul = img[:, :, 2].mean()

print("Rojo:", media_rojo)
print("Verde:", media_verde)
print("Azul:", media_azul)
# Out:
# Rojo: 133.204363822937
# Verde: 145.15760898590088
# Azul: 79.85263919830322

# %%
canales = ["Rojo", "Verde", "Azul"]
valores = [media_rojo, media_verde, media_azul]

plt.bar(canales, valores)
plt.ylabel("Intensidad promedio")
plt.title("Color promedio de la imagen")
plt.show()

# %%
datos = img.reshape(-1, 3)

df = pd.DataFrame(
    datos,
    columns=["Rojo", "Verde", "Azul"]
)

print(df.head())
# Out:
#    Rojo  Verde  Azul
# 0    29     46    10
# 1    27     44     8
# 2    30     45    12
# 3    28     43    10
# 4    29     43     8

# %%
plt.hist(img[:,:,2].ravel(), bins=50)
plt.title("Distribución del canal azul")
plt.xlabel("Intensidad")
plt.ylabel("Frecuencia")
plt.show()
